# %%
import pandas as pd

# %%
# !kaggle competitions download -c ml-intensive-yandex-autumn-2023
# Out:
# ...
#   0%|          | 0.00/988M [00:00<?, ?B/s]
#   0%|          | 1.00M/988M [00:00<10:14, 1.68MB/s]
#   0%|          | 2.00M/988M [00:00<05:10, 3.33MB/s]
#   0%|          | 4.00M/988M [00:00<02:53, 5.94MB/s]
#   1%|          | 6.00M/988M [00:01<02:15, 7.58MB/s]
#   1%|          | 8.00M/988M [00:01<01:54, 9.00MB/s]
#   1%|          | 10.0M/988M [00:01<01:48, 9.49MB/s]
#   1%|          | 12.0M/988M [00:01<01:39, 10.3MB/s]
#   1%|▏         | 14.0M/988M [00:01<01:37, 10.5MB/s]
#   2%|▏         | 16.0M/988M [00:02<01:37, 10.4MB/s]
#   2%|▏         | 18.0M/988M [00:02<01:32, 11.0MB/s]
#   2%|▏         | 20.0M/988M [00:02<01:33, 10.9MB/s]
#   2%|▏         | 22.0M/988M [00:02<01:29, 11.3MB/s]
#   2%|▏         | 24.0M/988M [00:02<01:27, 11.5MB/s]
#   3%|▎         | 26.0M/988M [00:02<01:28, 11.4MB/s]
#   3%|▎         | 28.0M/988M [00:03<01:28, 11.3MB/s]
#   3%|▎         | 30.0M/988M [00:03<01:40, 10.0MB/s]
#   3%|▎         | 32.0M/988M [00:03<01:28, 11.4MB/s]
# ...

# %%
df = pd.read_csv('train_answers.csv')
print(df.iloc[0])
# Out:
# id                0
# target_feature    0
# Name: 0, dtype: int64
